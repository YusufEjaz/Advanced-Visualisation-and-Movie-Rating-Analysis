# %%
import pandas as pd

# %%
movies=pd.read_csv('~/Downloads/P4-Movie-Ratings.csv')

# %%
movies
# Out:
#                                    Film      Genre  Rotten Tomatoes Ratings %  \
# 0                 (500) Days of Summer      Comedy                         87
# 1                           10,000 B.C.  Adventure                          9
# 2                            12 Rounds      Action                         30
# 3                             127 Hours  Adventure                         93
# 4                             17 Again      Comedy                         55
# 5                                  2012     Action                         39
# 6                            27 Dresses     Comedy                         40
# 7                      30 Days of Night     Horror                         50
# 8                    30 Minutes or Less     Comedy                         43
# 9                                 50/50     Comedy                         93
# 10                           88 Minutes      Drama                          5
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies[0:560]
# Out:
#                                    Film      Genre  Rotten Tomatoes Ratings %  \
# 0                 (500) Days of Summer      Comedy                         87
# 1                           10,000 B.C.  Adventure                          9
# 2                            12 Rounds      Action                         30
# 3                             127 Hours  Adventure                         93
# 4                             17 Again      Comedy                         55
# 5                                  2012     Action                         39
# 6                            27 Dresses     Comedy                         40
# 7                      30 Days of Night     Horror                         50
# 8                    30 Minutes or Less     Comedy                         43
# 9                                 50/50     Comedy                         93
# 10                           88 Minutes      Drama                          5
# ...

# %%
movies.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film                         559 non-null object
# Genre                        559 non-null object
# Rotten Tomatoes Ratings %    559 non-null int64
# Audience Ratings %           559 non-null int64
# Budget (million $)           559 non-null int64
# Year of release              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film', 'Genre', 'CriticRating', 'AudienceRating',
       'BudgetMillions', 'Year']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies
# Out:
#                                    Film      Genre  CriticRating  \
# 0                 (500) Days of Summer      Comedy            87
# 1                           10,000 B.C.  Adventure             9
# 2                            12 Rounds      Action            30
# 3                             127 Hours  Adventure            93
# 4                             17 Again      Comedy            55
# 5                                  2012     Action            39
# 6                            27 Dresses     Comedy            40
# 7                      30 Days of Night     Horror            50
# 8                    30 Minutes or Less     Comedy            43
# 9                                 50/50     Comedy            93
# 10                           88 Minutes      Drama             5
# 11                   A Dangerous Method      Drama            79
# 12            A Nightmare on Elm Street     Horror            13
# ...

# %%
movies[movies.Film == 'Youth in Revolt']
# Out:
#                 Film   Genre  CriticRating  AudienceRating  BudgetMillions  \
# 555  Youth in Revolt  Comedy            68              52              18
#
#      Year
# 555  2009

# %%
movies[(movies.CriticRating) > 90]
# Out:
#                        Film      Genre  CriticRating  AudienceRating  \
# 3                 127 Hours  Adventure            93              84
# 9                     50/50     Comedy            93              93
# 26             An Education      Drama            94              78
# 94              District 9      Action            91              81
# 100        Drag Me to Hell      Horror            92              61
# 105                   Drive   Thriller            93              79
# 113               Enchanted     Comedy            93              80
# 178                    Hugo  Adventure            93              84
# 196                Iron Man     Action            94              91
# 207                    Juno     Comedy            94              89
# 215              Knocked Up     Comedy            91              83
# 244       Midnight in Paris    Romance            93              84
# 248    Mission Impossible 4     Action            93              86
# ...

# %%
import seaborn as sns

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.Film=movies.Film.astype('category')

# %%
movies.Year=movies.Year.astype('category')

# %%
movies.Genre=movies.Genre.astype('category')

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=12,8
sns.set_style("darkgrid")
sns.set_palette('magma_r')

# %%
#Joint Plots

# %%
j=sns.jointplot(data=movies, x='CriticRating', y='AudienceRating', size=8)

# %%
j=sns.jointplot(data=movies, x='CriticRating', y='AudienceRating', size=8, kind='hex')

# %% [markdown]
# ---

# %%
#HISTOGRAM

# %%
m1=sns.distplot(movies.AudienceRating, bins=15)

# %%
n1=plt.hist(movies.AudienceRating, bins=15)

# %%
n1=plt.hist(movies.CriticRating, bins=15)

# %%
m1=sns.distplot(movies.CriticRating, bins=15)

# %% [markdown]
# ---

# %%
#Stacked Histograms

# %%
#movies[movies.Genre == 'Drama'].BudgetMillions
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins=15)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins=15)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins=15)
plt.show()

# %%
[[movies[movies.Genre == 'Action'].BudgetMillions],[movies[movies.Genre == 'Drama'].BudgetMillions]]
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,movies[movies.Genre == 'Drama'].BudgetMillions], \
         stacked=True)
plt.show()

# %%
list1=[]
labels1=[]
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    labels1.append(gen)
#print(list1)
h=plt.hist(list1, bins=30, stacked=True, rwidth=1, label=labels1)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %%
#KDE PLOT

# %%
vis1=sns.lmplot(data=movies, x="CriticRating", y="AudienceRating", fit_reg=False, hue= 'Genre', size=8, aspect=1)

# %%
k1=sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade=True, shade_lowest=False, cmaps='Reds')
kb1=sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmaps='Reds')

# %% [markdown]
# ---

# %%
#Working with Subplots

# %%
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)

# %%
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)

# %%
f, ax=plt.subplots(1,2, figsize=(16,8), sharex=True, sharey=True)
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=ax[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=ax[1])

# %%
ax
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1cfe3710>,
# ...
#       dtype=object)

# %% [markdown]
# ---

# %%
#Violin Plots

# %%
w=sns.boxplot(data=movies, x='Genre', y='CriticRating')

# %%
z=sns.violinplot(data=movies, x='Genre', y='CriticRating')

# %% [markdown]
# ---

# %%
#FacetGrids

# %%
f, ax= plt.subplots(1,2, figsize= (16,8) ) 
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=ax[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=ax[1])
